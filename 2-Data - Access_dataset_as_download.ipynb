# %%
from utils import *

# %%
from azureml.core import Workspace, Experiment

ws = Workspace.from_config()
exp = Experiment(workspace=ws, name='access_dataset_as_download')
# Out:
# ...
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.

# %%
from azureml.core import Dataset

dataset = Dataset.get_by_name(ws, "cifar-10")
dataset
# Out:
# {
#   "source": [
#     "('mldemoblob', '/mldata/cifar-10')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "bdbef82d-ec67-49ee-a27b-320bd3211805",
#     "name": "cifar-10",
#     "version": 1,
#     "description": "cifar-10 train images and labels",
#     "workspace": "Workspace.create(name='mldemows', subscription_id='292890d4-aa6d-4d5e-a085-97c80db3c30a', resource_group='mldemo')"
#   }
# }

# %%
# Checked and its root /tmp 
folder = '/tmp/cifar-10'
path = dataset.download(folder)
path
# Out:
# ['/tmp/cifar-10/.DS_Store',
#  '/tmp/cifar-10/train/1000.png',
#  '/tmp/cifar-10/train/10003.png',
#  '/tmp/cifar-10/train/10007.png',
#  '/tmp/cifar-10/train/10010.png',
#  '/tmp/cifar-10/train/10014.png',
#  '/tmp/cifar-10/train/10018.png',
#  '/tmp/cifar-10/train/10021.png',
#  '/tmp/cifar-10/train/10025.png',
#  '/tmp/cifar-10/train/10029.png',
#  '/tmp/cifar-10/train/10032.png',
#  '/tmp/cifar-10/train/10036.png',
#  '/tmp/cifar-10/train/1004.png',
#  '/tmp/cifar-10/train/10043.png',
#  '/tmp/cifar-10/train/10047.png',
#  '/tmp/cifar-10/train/10050.png',
#  '/tmp/cifar-10/train/10054.png',
#  '/tmp/cifar-10/train/10058.png',
#  '/tmp/cifar-10/train/10061.png',
#  '/tmp/cifar-10/train/10065.png',
#  '/tmp/cifar-10/train/10069.png',
#  '/tmp/cifar-10/train/10072.png',
#  '/tmp/cifar-10/train/10076.png',
#  '/tmp/cifar-10/train/1008.png',
#  '/tmp/cifar-10/train/10083.png',
#  '/tmp/cifar-10/train/10087.png',
#  '/tmp/cifar-10/train/10090.png',
#  '/tmp/cifar-10/train/10094.png',
# ...

# %%
from azureml.core import ScriptRunConfig
# TODO
# 1. Understand why it downlaoded again to a different local folder
# 2. dataset.as_named_input does not accept 'cifar-10' and accepts 'cifar_10'
# downloaded again to a different folder
# Downloading cifar_10 to /var/folders/bg/qstlmb2n6cncqw_g_cy3jgt00000gn/T/cifar_10_bdbef82d-ec67-49ee-a27b-320bd3211805
src = ScriptRunConfig(source_directory="code",
                      script='access_dataset.py',
                      arguments=['--input', dataset.as_named_input('cifar_10').as_download()],
                      environment=get_current_env())

# Submit the run configuration for your training run
run = exp.submit(src)
run.wait_for_completion(show_output=True)
# Out:
# RunId: access_dataset_as_download_1669540449_08f35b37
# Web View: https://ml.azure.com/runs/access_dataset_as_download_1669540449_08f35b37?wsid=/subscriptions/292890d4-aa6d-4d5e-a085-97c80db3c30a/resourcegroups/mldemo/workspaces/mldemows&tid=03ff20ec-51f3-415c-9462-b61ddcf1ce16
#
# Streaming azureml-logs/70_driver_log.txt
# ...
#
# [2022-11-27T09:14:13.776419] Entering context manager injector.
# [2022-11-27T09:14:15.203068] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['access_dataset.py', '--input', 'DatasetConsumptionConfig:cifar_10'])
# [2022-11-27T09:14:16.791] Initialize DatasetContextManager.
# Script type = None
# Set Dataset cifar_10's target path to /var/folders/bg/qstlmb2n6cncqw_g_cy3jgt00000gn/T/cifar_10_bdbef82d-ec67-49ee-a27b-320bd3211805
# ...
