# %%
from utils import *

# %%
from azureml.core import Workspace, Experiment
ws = Workspace.from_config()
exp = Experiment(workspace=ws, name='access_data_from_path')
# Out:
# Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.

# %%
import pandas as pd

path ='https://dprepdata.blob.core.windows.net/demo/Titanic.csv'
df = pd.read_csv(path)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
from azureml.core import ScriptRunConfig

src = ScriptRunConfig(source_directory="code",
                      script='access_data_from_path.py',
                      arguments=['--input', path],
                      environment=get_current_env())

# Submit the run configuration for your training run
run = exp.submit(src)
run.wait_for_completion(show_output=True)
# Out:
# RunId: access_data_from_path_1669199108_c9fccc5c
# Web View: https://ml.azure.com/runs/access_data_from_path_1669199108_c9fccc5c?wsid=/subscriptions/292890d4-aa6d-4d5e-a085-97c80db3c30a/resourcegroups/mldemo/workspaces/mldemows&tid=03ff20ec-51f3-415c-9462-b61ddcf1ce16
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# [2022-11-23T10:25:11.571482] Entering context manager injector.
# [2022-11-23T10:25:13.125267] context_manager_injector.py Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['access_data_from_path.py', '--input', 'https://dprepdata.blob.core.windows.net/demo/Titanic.csv'])
# Script type = None
# [2022-11-23T10:25:13.140900] Entering Run History Context Manager.
# [2022-11-23T10:25:15.317695] Current directory: /private/var/folders/bg/qstlmb2n6cncqw_g_cy3jgt00000gn/T/azureml_runs/access_data_from_path_1669199108_c9fccc5c
# [2022-11-23T10:25:15.320250] Preparing to call script [access_data_from_path.py] with arguments:['--input', 'https://dprepdata.blob.core.windows.net/demo/Titanic.csv']
# [2022-11-23T10:25:15.328796] After variable expansion, calling script [access_data_from_path.py] with arguments:['--input', 'https://dprepdata.blob.core.windows.net/demo/Titanic.csv']
#
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]
#
#
# [2022-11-23T10:25:17.988246] The experiment completed successfully. Finalizing run...
# [2022-11-23T10:25:17.988354] Start FinalizingInRunHistory
# [2022-11-23T10:25:18.000768] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 37087
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 3 items cleaning up...
# Cleanup took 0.4212198257446289 seconds
# [2022-11-23T10:25:19.343560] Finished context manager injector.
#
# Execution Summary
# =================
# RunId: access_data_from_path_1669199108_c9fccc5c
# Web View: https://ml.azure.com/runs/access_data_from_path_1669199108_c9fccc5c?wsid=/subscriptions/292890d4-aa6d-4d5e-a085-97c80db3c30a/resourcegroups/mldemo/workspaces/mldemows&tid=03ff20ec-51f3-415c-9462-b61ddcf1ce16
# {'runId': 'access_data_from_path_1669199108_c9fccc5c',
#  'target': 'local',
#  'status': 'Completed',
#  'startTimeUtc': '2022-11-23T10:25:11.082394Z',
#  'endTimeUtc': '2022-11-23T10:26:23.337353Z',
#  'services': {},
#  'properties': {'_azureml.ComputeTargetType': 'local',
#   'ContentSnapshotId': '28a5cfb1-b435-4516-b99c-f67d90e9bde2',
#   'azureml.git.repository_uri': 'https://github.com/mahtabsyed/Azure-Machine-Learning-Demo.git',
#   'mlflow.source.git.repoURL': 'https://github.com/mahtabsyed/Azure-Machine-Learning-Demo.git',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.commit': 