# %%
from azureml.opendatasets import PublicHolidays
from datetime import datetime
from dateutil.relativedelta import relativedelta


# https://learn.microsoft.com/en-us/python/api/azureml-opendatasets/azureml.opendatasets?view=azure-ml-py

end_date = datetime.today()
start_date = datetime.today() - relativedelta(months=1)
hol = PublicHolidays(start_date=start_date, end_date=end_date)
hol_df = hol.to_pandas_dataframe()
hol_df
# Out:
# [Info] read from /var/folders/bg/qstlmb2n6cncqw_g_cy3jgt00000gn/T/tmpcxbjqlcb/https%3A/%2Fazureopendatastorage.azurefd.net/holidaydatacontainer/Processed/part-00000-tid-8468414522853579044-35925ba8-a227-4b80-9c89-17065e7bf1db-649-c000.snappy.parquet
#       countryOrRegion                                        holidayName  \
# 27476         Hungary                                      Nemzeti ünnep
# 27477          Norway                                             Søndag
# 27478          Sweden                                             Söndag
# 27479     New Zealand                                         Labour Day
# 27480         Austria                                   Nationalfeiertag
# 27481           Czech     Den vzniku samostatného československého státu
# 27482          Norway                                             Søndag
# 27483          Sweden                                             Söndag
# 27484         Hungary                     Mindenszentek előtti pihenőnap
# 27485         Ireland                               October Bank Holiday
# 27486        Slovenia                                    dan reformacije
# 27487         Austria                                      Allerheiligen
# 27488         Belgium                                      Allerheiligen
# 27489         Croatia                                          Svi sveti
# 27490          France                                          Toussaint
# 27491         Hungary                                      Mindenszentek
# 27492           Italy                                      Tutti i Santi
# 27493          Poland                    Uroczystość Wszystkich świętych
# 27494        Portugal                             Dia de Todos os Santos
# 27495        Slovenia                               dan spomina na mrtve
# 27496           Spain                                   Todos los Santos
# 27497          Brazil                                            Finados
# 27498           Japan                                               文化の日
# 27499         Finland                                        Pyhäinpäivä
# 27500          Sweden                                   Alla helgons dag
# 27501          Norway                                             Søndag
# 27502          Sweden                                             Söndag
# 27503         Belarus                         День Октябрьской революции
# 27504        Colombia  Dia de Todos los Santos [All Saint's Day](Obse...
# 27505         Belgium                                     Wapenstilstand
# 27506          France                                     Armistice 1918
# 27507          Poland                     Narodowe Święto Niepodległości
# 27508   United States                                       Veterans Day
# 27509          Norway                                             Søndag
# 27510          Sweden                                             Söndag
# 27511        Colombia  Independencia de Cartagena [Independence of Ca...
# 27512          Brazil                           Proclamação da República
# 27513           Czech                   Den boje za svobodu a demokracii
# 27514         Croatia                                       Dan sjećanja
# 27515       Argentina  Día Nacional de la Soberanía [National Soverei...
# 27516          Mexico              Día de la Revolución [Revolution Day]
# 27517          Norway                                             Søndag
# 27518          Sweden                                             Söndag
# 27519          Mexico   Día de la Revolución [Revolution Day] (Observed)
#
#                                     normalizeHolidayName isPaidTimeOff  \
# 27476                                      Nemzeti ünnep          None
# 27477                                             Søndag          None
# 27478                                             Söndag          None
# 27479                                         Labour Day          None
# 27480                                   Nationalfeiertag          None
# 27481     Den vzniku samostatného československého státu          None
# 27482                                             Søndag          None
# 27483                                             Söndag          None
# 27484                     Mindenszentek előtti pihenőnap          None
# 27485                               October Bank Holiday          None
# 27486                                    dan reformacije          None
# 27487                                      Allerheiligen          None
# 27488                                      Allerheiligen          None
# 27489                                          Svi sveti          None
# 27490                                          Toussaint          None
# 27491                                      Mindenszentek          None
# 27492                                      Tutti i Santi          None
# 27493                    Uroczystość Wszystkich świętych          None
# 27494                             Dia de Todos os Santos          None
# 27495                               dan spomina na mrtve          None
# 27496                                   Todos los Santos          None
# 27497                                            Finados          None
# 27498                                               文化の日          None
# 27499                                        Pyhäinpäivä          None
# 27500                                   Alla helgons dag          None
# 27501                                             Søndag          None
# 27502                                             Söndag          None
# 27503                         День Октябрьской революции          None
# 27504          Dia de Todos los Santos [All Saint's Day]          None
# 27505                                     Wapenstilstand          None
# 27506                                     Armistice 1918          None
# 27507                     Narodowe Święto Niepodległości          None
# 27508                                       Veterans Day         False
# 27509                                             Søndag          None
# 27510                                             Söndag          None
# 27511  Independencia de Cartagena [Independence of Ca...          None
# 27512                           Proclamação da República          None
# 27513                   Den boje za svobodu a demokracii          None
# 27514                                       Dan sjećanja          None
# 27515  Día Nacional de la Soberanía [National Soverei...          None
# 27516              Día de la Revolución [Revolution Day]          None
# 27517                                             Søndag          None
# 27518                                             Söndag          None
# 27519              Día de la Revolución [Revolution Day]          None
#
#       countryRegionCode       date
# 27476                HU 2022-10-23
# 27477                NO 2022-10-23
# 27478                SE 2022-10-23
# 27479                NZ 2022-10-24
# 27480                AT 2022-10-26
# 27481                CZ 2022-10-28
# 27482                NO 2022-10-30
# 27483                SE 2022-10-30
# 27484                HU 2022-10-31
# 27485                IE 2022-10-31
# 27486                SI 2022-10-31
# 27487                AT 2022-11-01
# 27488                BE 2022-11-01
# 27489                HR 2022-11-01
# 27490                FR 2022-11-01
# 27491                HU 2022-11-01
# 27492                IT 2022-11-01
# 27493                PL 2022-11-01
# 27494                PT 2022-11-01
# 27495                SI 2022-11-01
# 27496                ES 2022-11-01
# 27497                BR 2022-11-02
# 27498                JP 2022-11-03
# 27499                FI 2022-11-05
# 27500                SE 2022-11-05
# 27501                NO 2022-11-06
# 27502                SE 2022-11-06
# 27503                BY 2022-11-07
# 27504                CO 2022-11-07
# 27505                BE 2022-11-11
# 27506                FR 2022-11-11
# 27507                PL 2022-11-11
# 27508                US 2022-11-11
# 27509                NO 2022-11-13
# 27510                SE 2022-11-13
# 27511                CO 2022-11-14
# 27512                BR 2022-11-15
# 27513                CZ 2022-11-17
# 27514                HR 2022-11-18
# 27515                AR 2022-11-20
# 27516                MX 2022-11-20
# 27517                NO 2022-11-20
# 27518                SE 2022-11-20
# 27519                MX 2022-11-21
